# %%
# %%pyspark
# df = spark.read.load('abfss://aceabf52-d605-424a-bf4b-c41ada4dd3d3@onelake.dfs.fabric.microsoft.com/eb83e950-65b8-40ef-b59d-d83263cdb31f/Tables/sales')
# display(df.limit(10))
# Out:
# StatementMeta(, b63daa10-68f7-40c1-9a90-577ab7db3da5, 33, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 21795b78-1b4a-4e1a-bced-262a79e75284)
